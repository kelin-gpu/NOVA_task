# %%
import os
from openai import OpenAI

# %%
os.environ["DASHSCOPE_API_KEY"] = ""  # 您的百炼API Key

# %%
prompt = f"""
你是一名高效的信息分析助手，任务是从聊天记录中提取出所有与“重要事件”、“任务安排”、“截止日期（DDL）”、“会议”、“作业提交”、“项目进展”相关的信息，并生成一份清晰简洁的通知摘要。

请遵循以下要求：
1. 从原始聊天内容中提取所有有明确时间、任务、事件的内容（包括隐含的日期/时间）。
2. 使用清晰的条目或编号列表，按时间顺序排列。
3. 每个事件请包含以下信息：
   - 【事件内容】
   - 【截止时间 / 发生时间】（若未明确给出，请根据上下文合理推测并标记为“可能”  ）
   - 【消息发送时间】如果有消息发送时间，可以额外添加进去
   - 【责任人或相关人员】（如有）
4. 输出一份简洁的“通知摘要”，语言应正式、清晰，适合直接发送给团队成员。
5. 输出格式示例：

---
**通知摘要：**

1. 🕓 【事件】提交《人工智能实验报告》
   - 截止时间：10月22日 23:59
   - 责任人：全体同学
   - 消息发送时间：10月20日 23:59

2. 📅 【事件】项目组会议
   - 时间：10月24日下午2点
   - 参与人：A、B、C
   - 消息发送时间：10月23日 23:59
"""

# %%
def call_qwen_model(message):
    # 初始化客户端
    client = OpenAI(
        api_key=os.getenv("DASHSCOPE_API_KEY"),
        base_url="https://dashscope.aliyuncs.com/compatible-mode/v1",
    )

    # 调用模型
    completion = client.chat.completions.create(
        model="qwen-plus",  # 也可以尝试 "qwen-turbo" 或 "qwen-max"
        messages=[
            {"role": "system", "content": prompt},
            {"role": "user", "content":  f"以下是聊天记录，请生成通知摘要：\n\n{message}"},
        ],
        temperature=0.5,
        max_tokens=32768
    )

    # 提取模型输出
    x = completion.choices[0].message.content.strip()
    return x

# %%
x = str()
y = "\n"
x = x + y
x
# Out:
# '\n'

# %%
combine = str()
for i in range(10):
    if __name__ == "__main__":
        # === 1️⃣ 从 txt 文件中读取内容 ===
        txt_path = fr"D:\google_dl\Nova\nova_qq_message\qq_message_txt_to_other\split_lines_{i+1}.txt"  # 你的 txt 文件路径
        with open(txt_path, "r", encoding="utf-8") as f:
            message = f.read().strip()
        # === 2️⃣ 调用模型 ===
        result = call_qwen_model(message)
        combine = combine + result + "\n"

# %%
print(combine)
# Out:
# ---
# **通知摘要：**
#
# 1. 🌐 【事件】获取校园VPN服务
#    - 内容：校外访问校内资源需使用南大VPN，登录地址为 `https://vpn.nju.edu.cn`。若收不到短信验证码，请前往统一身份认证平台（[https://authserver.nju.edu.cn](https://authserver.nju.edu.cn)）绑定手机号。
#    - 消息发送时间：2022-06-27 至 2022-08-19
#
# 2. 🏥 【事件】核酸检测点及出结果时间
#    - 内容：校内常态化核酸采样点位于**游泳馆**或**体育馆**（视通知安排），一般在第二天上午出结果（如早上做，次日10点左右；下午做，次日13点左右）。泰康医院、鼓楼医院等校外机构可做加急核酸，最快5–6小时出结果。
#    - 注意事项：全员检测期间可能因样本量大延迟出结果，建议急需出行者选择单检或校外机构。
#    - 消息发送时间：2022-06-27 至 2022-08-16
#
# 3. 🔐 【事件】校园码异常处理（灰码/紫码）
#    - 内容：若因出校未刷卡导致校园码变灰，需通过“入校健康填报”和“行程上报”流程恢复绿码，无需销假。紫码为校外住宿标识，管理权限不同。
#    - 处理方式：联系辅导员协助变更状态，或重新提交审批流程。
#    - 消息发送时间：2022-06-27 至 2022-08-14
#
# 4. 🚌 【事件】离返校交通与防疫要求
#    - 内容：南京南站、南京站进站**不强制查验核酸**，但需根据目的地城市政策准备相应证明（可通过“国务院客户端”小程序查询）。乘坐小蓝鲸巴士需提前加入指定群聊关注发车安排。
#    - 建议：出行前务必确认出发地与目的地最新防疫政策。
#    - 消息发送时间：2022-06-27 至 2022-08-19
#
# 5. 📚 【事件】图书馆与自习室开放情况
#    - 内容：暑假期间图书馆正常开放，逸夫楼A/B/C区一至三层供自习使用。研讨室可通过 [ytj.nju.edu.cn](http://ytj.nju.edu.cn) 预约。
#    - 关闭提醒：琴房、部分教学楼教室暑期关闭。
#    - 消息发送时间：2022-07-04 至 2022-08-09
#
# 6. 🍱 【事件】食堂与商业服务运营信息
#    - 内容：
#      - 菜根谭：营业时间为9:00起，可代收快递。
#      - 罗森便利店：营业时间为7:00至次日凌晨1:00。
#      - 雅思园、大唐快餐、巴黎贝甜等假期照常营业。
#      - 宿舍楼下快递点已整合至菜根谭，京东可上门取件。
#    - 消息发送时间：2022-06-30 至 2022-08-06
#
# 7. 🎒 【事件】开学返校安排
#    - 内容：老生正式上课时间为 **9月5日**，返校时间预计为 **9月3日至4日**，允许提前1–2天返校。具体以学工部门发布的疫情防控安排为准。
#    - 提醒：返校需提前完成“行程上报”和“入校健康填报”，建议至少提前1–2天提交申请，避免审批延误。
#    - 消息发送时间：2022-08-13 至 2022-08-18
#
# 8. 💉 【事件】九价HPV疫苗接种咨询
#    - 内容：接种地点为**鼓楼医院社区卫生服务中心**（汉口路小门），费用约为1318元/针。咨询电话：025-83592526 或 025-89685120（防保科）。
#    - 消息发送时间：2022-06-28 至 2022-08-08
#
# 9. 🧾 【事件】成绩单与在读证明办理
#    - 内容：在校生可通过信息门户自助打印成绩单；已离校者可委托他人持取件码至行政北楼自助机领取。在读证明可通过APP申请，由他人代取。
#    - 消息发送时间：2022-07-02 至 2022-07-04
#
# 10. ⚠️ 【提醒】谨防诈骗与违规行为
#     - 内容：切勿点击来源不明的链接，部分邮件可能为盗号诈骗。群内禁止发放红包拉票，问卷填写应自愿参与。
#     - 消息发送时间：2022-06-28 至 2022-08-14
#
# ---
# 📌 **温馨提示**：以上信息基于群聊记录整理，涉及防疫政策、服务开放等动态内容，请持续关注学校官方通知或咨询相关部门获取最新信息。
# ---
# **通知摘要：**
#
# 1. 📅 【事件】大创项目结项时间
#    - 信息来源：往年文件
#    - 预计时间：一般在每年11月至12月
#    - 公布平台：南京大学大创网站
#    - 消息发送时间：2022-08-19
#
# 2. 🧪 【事件】返校防疫要求（非中高风险地区）
#    - 要求：无需两周隔离，目前执行“七天五检”核酸检测政策
#    - 出行限制：返校后无两小时出校限制，实行24小时进出制（当天返回即可）
#    - 消息发送时间：2022-08-19 至 2022-08-20
#
# 3. 🔐 【事件】南大邮箱微信扫码认证即将启用 + 账号清理提醒
#    - 启用时间：2022年8月25日起
#    - 重要提醒：凡半年及以上未登录的邮箱账户将被暂停使用（可收信但无法登录）
#    - 恢复方式：通过OA申请，审核后2个工作日内恢复
#    - 建议：确保在2022年2月26日后至少成功登录过一次
#    - 来源链接：https://itsc.nju.edu.cn/ea/57/c21415a584279/pagem.htm
#    - 消息发送时间：2022-08-22
#
# 4. 🏥 【事件】急救培训志愿者招募（军训期间）
#    - 时间：2022年8月22日至24日
#    - 内容：面向2021级学生开展急救培训，需掌握AED、CPR等基础技能
#    - 形式：老师:志愿者 = 1:1 协助讲课
#    - 招募对象：在校符合条件的学生
#    - 消息发送时间：2022-08-21
#
# 5. 🍱 【服务信息】清真食堂已开放
#    - 状态：已开放
#    - 消息确认时间：2022-08-21
#
# 6. ☕ 【服务信息】计科楼咖啡厅营业时间
#    - 营业时间：约至下午五六点左右
#    - 消息确认时间：2022-08-22
#
# 7. 🗓️ 【事件】补退选时间安排
#    - 开始时间：正式开学第一天中午13:30
#    - 备注：体育课、悦读类课程补选时间为9月19日13:30
#    - 消息发送时间：2022-08-22 至 2022-09-04
#
# 8. 🧾 【事项】大创项目报销要求
#    - 必须材料：发票
#    - 消息确认时间：2022-08-29
#
# 9. 💉 【疫苗接种】九价HPV疫苗预约与接种说明
#    - 预约方式：通过校医院系统抢号（可能出现延迟或临时开放）
#    - 缴费方式：现场缴纳，无需挂号（预约成功后刷校园卡+身份证）
#    - 单价：1318元/针
#    - 注意事项：第二、三针通常不需抢号，由学校统一安排；若错过可在现场协调
#    - 消息发送时间：2022-08-28 至 2022-08-29
#
# 10. 🚪 【出入管理】入校审批与校园码规则
#     - 审批原则：审批完成时间不得晚于申请入校时间，否则需重新申请
#     - 校园码变绿时间：入校当日零点后陆续变为绿色（部分为凌晨2点左右），此前为灰色属正常
#     - 行程上报修改：可以修改
#     - 消息发送时间：2022-08-19 至 2022-08-31
#
# 11. 📞 【联系方式】校内常用服务电话
#     - 校医院牙科咨询：89685120
#     - ITSC反馈方式：电话 89683791（每日8:00–19:00）或微信公众号“南京大学信息门户”
#     - 教务处官网电话查询：https://jw.nju.edu.cn/c9/c4/c24683a510404/page.htm
#     - 消息发送时间：2022-08-26 至 2022-08-24
#
# 12. 🏫 【设施开放情况汇总】
#     - 图书馆：正常开放，开放时间 8:00–22:30
#     - 鼓楼图书馆装修状态：尚未完成
#     - 浴室开放时间：17:30–22:00（部分宿舍楼最晚11:30停水）
#     - 九食堂及其他食堂：均已开放
#     - 西门关闭时间：晚上10:00
#     - 消息发送时间：2022-08-27 至 2022-08-31
#
# 13. 📡 【网络与技术问题】
#     - 校园网连接问题：建议多次尝试、清除缓存或切换浏览器；部分设备需开启“无感知认证”
#     - 南小宝APP下载问题：服务器迁移中，暂无法稳定访问；替代方案可通过 njuer.top 获取资源
#     - 南大云盘、邮箱、p.nju.edu.cn 登录异常：存在阶段性系统故障，建议稍后重试
#     - 消息发送时间：2022-08-20 至 2022-09-11
#
# 14. 📨 【其他重要提示】
#     - 新生家长不可进校
#     - 实习证明无统一模板
#     - 户籍迁至学校的同学，“户口所在地派出所”应填写实际归属派出所名称，非“南京大学”
#     - 学费缴纳时间预计在9月下旬，具体金额可参考去年记录
#     - 悦读学分认定周期较长，通常在开学后1–2个月内陆续更新
#     - 消息发送时间：2022-08-20 至 2022-09-04
#
# ---
# > 注：以上信息基于群聊内容整理，部分政策可能存在动态调整，请以官方最新通知为准。
# ---
# **通知摘要：**
#
# 1. 📅 **课程安排与会议信息**
#    - 【事件】全球变化与人类活动课程使用腾讯会议上课
#      - 会议号：151-293-547，密码：339341（网络研讨会形式）
#      - 消息发送时间：2022-09-13 18:33:55
#    - 【事件】中国陶瓷鉴定课程线上链接更新
#      - 腾讯会议链接：https://meeting.tencent.com/dm/J4DAGUEH7O3n
#      - 消息发送时间：2022-09-15 14:11:21
#    - 【事件】揭秘肿瘤课程会议号
#      - 会议号：138-816-481
#      - 消息发送时间：2022-09-15 18:25:38
#
# 2. 🗓️ **补选/退课相关时间点**
#    - 【事件】阅读课与22级补退选开放时间
#      - 时间：9月19日 13:30
#      - 消息发送时间：2022-09-14 11:02:54 / 2022-09-14 14:45:54
#    - 【事件】体育课名额增加通知
#      - 周四中午释放新名额
#      - 消息发送时间：2022-09-19 19:56:11
#
# 3. 💡 **重要提醒与校园动态**
#    - 【事件】学费扣款时间确认
#      - 预计9月27日统一扣除；若余额不足可通过“南京大学财务处”公众号自助缴费。
#      - 消息来源：2022-09-23 至 2022-09-27 多条记录
#    - 【事件】校内通行权限调整
#      - 社会学院通知老生为一小时通行权限（非最终全校政策），后续恢复正常进出。
#      - 消息发送时间：2022-09-16 15:25:39 / 2022-09-23 15:03:26
#    - 【事件】九价疫苗暂停接种
#      - 因鼓楼校区混采阳性风险，原定接种暂停，等待后续通知。
#      - 消息发送时间：2022-09-20 9:36:18
#
# 4. 🏥 **校医院与医疗服务说明**
#    - 【事件】校医院可提供服务范围
#      - 可开具晕车药、感冒药、口腔溃疡药物（部分医生建议自购）；
#      - 可进行补牙，报销比例约70%；
#      - 工作日可挂耳鼻喉科、口腔科，周末仅急诊。
#      - 消息来源：2022-10 上旬多条记录
#    - 【事件】转诊与报销规则
#      - 非急诊需提前开好转诊单方可报销；
#      - 一次转诊对应一次报销，多次就诊需多次转诊。
#      - 消息发送时间：2022-09-21 16:40:51 / 2022-10-10 15:51:06
#
# 5. 🔐 **系统与账号问题**
#    - 【事件】南大邮箱初始密码
#      - 初始密码为身份证号码
#      - 消息发送时间：2022-10-09 19:22:23
#    - 【事件】校园网认证失败解决方式
#      - 关闭手机流量后尝试手动访问 p.nju.edu.cn 或通过VPN登录充值。
#      - 消息来源：2022-09-15 / 2022-10-10 相关讨论
#
# 6. 🧹 **生活服务信息汇总**
#    - 【地点】证件照拍摄：大唐影楼
#    - 【地点】洗衣干洗：四栋楼下洗衣房（非四栋也可使用）
#    - 【地点】修表/修眼镜：一栋楼下电脑医院或眼镜店柜台
#    - 【地点】电动车维修：环境学院或生命科学学院楼后、三栋车库
#    - 【联系方式】快递代取：姓赵的叔叔，电话 15152316566
#    - 消息来源：2022-09 至 10月期间多条问答
#
# 7. 📢 **其他注意事项**
#    - 【提示】宿舍门禁系统曾出现故障（10月11日），部分新卡无法刷开，已报修处理。
#    - 【提示】图书馆书籍状态“阅览”表示仅限馆内阅读，不可外借。
#    - 【提示】电子成绩单可在“南大APP”→“自助服务”中申请下载。
#
# ---
# > 注：以上信息基于群聊内容整理，具体以学校官方通知为准。建议关注“南京大学财务处”、“南大信息门户”等官方平台获取权威信息。
# ---
# **通知摘要：**
#
# 1. 📅 **疫情防控与校园出入政策更新**
#    - 因南京市及栖霞区疫情防控政策暂不调整，**11月2日继续执行封控管理**，原定解封时间（11月1日24时）未解除。
#    - 自11月6日起，**两校区恢复通行**，但初期仍限制外出时间为2小时。
#    - **11月8日后取消出校时间限制**，实行常态化管理，无需向辅导员报备短时出校。
#    - 出校码在凌晨0-2点期间可能随机变灰，需通过销假流程申请恢复。
#
# 2. 🚇 **校外交通与核酸检测要求**
#    - 坐地铁需持**48小时内核酸阴性证明**，可通过“我的南京”App查看采样时间作为凭证。
#    - 校外推荐检测点：**仙林泰康医院（可做加急3小时出结果）**。
#    - 校内常规检测点包括：**游泳馆、仙二北门、教学楼等**，部分时段为全员检测。
#
# 3. 📦 **快递收发情况更新**
#    - 可正常接收的快递公司：**京东、顺丰、EMS、中通、圆通**。
#    - 暂无法派送：申通（后于11月7日确认已恢复）。
#    - 邮政快递每日固定进校一次，可正常收取。
#    - 退货支持上门取件（如京东、顺丰），菜鸟裹裹也可使用。
#    - 提货点信息：
#      - 天猫超市 → 菜根谭
#      - 安迅物流 → 菜根谭附近
#
# 4. 🍱 **餐饮与生活服务动态**
#    - 瑞幸咖啡：暂停营业，**12月3日起恢复正常营业**。
#    - 麦当劳：因访客系统问题，曾短暂调整营业时间（11月6日通知：当日11:00–19:00；后续恢复7:00–23:00）。
#    - 勇园快递中心：已关闭。
#    - 金陵小炒可代加工螃蟹，费用约5元/只。
#
# 5. 🎓 **课程与教学安排**
#    - **逻辑思维与表达**（王克喜老师）：
#      - 会议密码：123456
#      - 期末论文要求：提交一份2000字以上A4打印稿，主题与逻辑相关。
#    - **中华民国史专题研究**（张生老师）旁听会议号：腾讯会议 892-5472-4192，密码 194910。
#    - **艺术传播与历史**会议号：562-6991-6346。
#    - **俄罗斯文学经典的当代意义**：有同学反映尚未明确期末作业要求，建议联系任课教师确认。
#
# 6. 🏃‍♂️ **体测相关重要通知**
#    - 室外体测开放时间：周末下午13:30–16:00，最后一次安排为**12月3日**。
#    - 室内体测可预约至12月初，大三学生也可参与。
#    - 成绩查询说明：
#      - APP上成绩更新延迟，以**方肇周体育馆外机器显示为准**。
#      - 若APP缺项但机器上有记录，视为有效，必要时拍照留存并向体育部办公室反馈补录。
#      - 总分满50分即合格，单项不强制及格。
#    - 缓测/免测：
#      - 免测需医院证明并填写申请表。
#      - 缓测申请交至体育部办公室。
#    - 测试须知：
#      - 室外项目无需校园卡，扫码登记即可。
#      - 室内项目建议携带校园卡，人脸识别为主。
#
# 7. 💊 **校医院与医疗事项**
#    - 急诊可处理外伤、感冒等，无需转诊，但需保留急诊病历用于报销。
#    - 打破伤风需转诊或直接挂急诊（鼓楼医院可行）。
#    - 报销周期较长，通常一学期到账一次。
#    - 工作时间：门诊至17:00，急诊全天开放。
#
# 8. 🧾 **其他实用信息**
#    - 学生证补办 → 联系教务员
#    - 校园卡补办/照片更换 → ITSC服务中心（现场办理）
#    - 南大邮箱登录问题 → 使用学号@smail.nju.edu.cn +身份证后六位，长期未登录会被停用
#    - 行政北楼自助打印机可用微信门户免密打印
#    - 租借正装地点：科学园创新创业学院一楼、“第二颗纽扣”（就业中心，待确认是否仍在运营）
#
# 9. ⏰ **近期重要时间节点**
#    - 运动会：**11月25–26日**
#    - 期末考试安排：预计**12月初发布**，本科生院已回应将在下周确定
#    - 六级报名错过 → 需等待下一年度
#
# 10. 🔔 **温馨提示**
#     - 校园码变灰常见原因：未按时做核酸、行程涉及高风险区、进出未刷卡、系统异常。解决方式：联系辅导员进行三级审批恢复。
#     - 宿舍用电功率限制约为1000W，超过可能跳闸。
#     - 图书馆借书逾期1–2天一般无罚款，长期未还将影响信用。
#
# ---
# 请各位同学根据最新通知合理安排学习与生活，关注官方渠道发布的正式文件，祝大家顺利！
# ---
# **通知摘要：**
#
# 1. 📅 **体测成绩更新与补测安排**
#    - 【事件】室外及室内体测成绩已于12月5日陆续录入系统，此前未显示成绩的同学可重新查看南大APP。
#    - 【说明】若仍未显示，建议前往方肇周体育馆114办公室咨询或申诉（部分同学反映周六上午9-11点可办理）。
#    - 【补测】未完成体测者无需申请补测，下学期将开放补测预约，通过南大APP预约即可。
#
# 2. 🏫 **校园服务与设施信息**
#    - 【大唐文化】营业时间调整为9:00–17:00，可提供打印、扫描、证件照等服务。
#    - 【自助打印】行政处自助打印机故障时，可前往图书馆后方信息化服务大厅使用备用设备。
#    - 【校园卡】如遇消磁或丢失，请前往ITSC办理补办；更换照片需先发邮件再现场办理。
#    - 【研讨间预约】每日0点起可预约两天后的研讨室，可通过图书馆系统操作。
#
# 3. 🧪 **核酸检测与医疗服务**
#    - 【校医院核酸】单管自费检测时间为工作日上午8:00–11:45、下午13:30–17:00，费用约16元，结果约24小时内出具（可在苏康码或迪飞医学公众号查询）。
#    - 【抗原试剂】校医院暂无对外售卖，校外药店（如先声再康、益丰大药房）限量限购。
#    - 【门诊报销】校外就诊原则上需提前转诊方可报销；急诊可事后补办转诊手续，但最终以工作人员审核为准。
#
# 4. 📚 **教学与考试相关通知**
#    - 【四六级考试】
#      - 需携带身份证和准考证（黑白打印有效），耳机自备（推荐带备用电池或备用耳机）；
#      - 考试当天无需核酸证明；
#      - 因疫情无法返校者须于12月8日前提交延期申请，否则视为缺考。
#    - 【学位英语】需自备耳机，考场不统一配发收音机。
#    - 【课程考核】多门通识课（如《韩剧中的婚姻与家庭研究》《汪伪政权研究》《俄罗斯文学经典的当代意义》）已明确论文提交方式及DDL，请关注课程群或教师通知。
#    - 【缓考/延考】学院统一组织的延期考试仍需在教务系统中提交申请，请及时联系教务员确认流程。
#
# 5. 🛫 **出行与物流提示**
#    - 【机场交通】仙林校区至禄口机场打车约1小时，地铁约2小时；拼车需求可通过表白墙或群内协调。
#    - 【快递服务】德邦快递支持宿舍楼下取件；菜鸟驿站提供上门取件并自带称重工具。
#    - 【高铁学生票】本学期仍需进行资质核验后方可购买学生优惠票。
#
# 6. 🔐 **系统与账号问题**
#    - 【南大APP】请销假功能异常时，可尝试清除记录或联系辅导员协助处理；出校后校园码将在当日24:00变灰。
#    - 【VPN访问】网址为 `vpn.nju.edu.cn` 或 `vpn3.nju.edu.cn`，忘记密码可通过学校账户系统找回。
#    - 【知网访问】校外可通过VPN登录，若无法连接建议刷新多次或切换网络环境。
#
# 7. 🗣️ **其他重要提醒**
#    - 【西门开放时间】7:00–24:00，允许行人通行。
#    - 【临时困难补助】由学生资助中心审核，材料交至行政北楼124室。
#    - 【寒假社会实践】2023年冬季社会实践群已建立，有需要者可联系相关负责人加入。
#    - 【经典悦读考试】未选修相应阅读类课程的学生可通过悦读测试获得学分认定，具体安排由学委通知。
#
# 8. ⚠️ **特别注意**
#    - 四六级无故缺考可能影响后续报考资格（尤其在考位紧张情况下），建议慎重决定是否参加。
#    - 校园卡、医保报销、成绩单打印等事务请尽早办理，避免假期延误。
#
# ---
# 📌 建议同学们密切关注各课程群、教务系统及辅导员通知，确保重要事项不遗漏。
# 如有紧急问题，可直接联系相关部门或寻求辅导员帮助。
# ---
# **通知摘要：**
#
# 1. 🌐 【事件】校园网访问问题
#    - 说明：部分用户反映校园网连接不稳定或显示“请重新获取地址”，建议关闭手机流量后重新连接，或通过南大信息门户报障。
#    - 消息时间：2023-02-12 至 2023-03-14
#
# 2. 🏫 【事件】校外人员入校政策
#    - 说明：目前访客需通过预约申请方可进校，审核人一般为辅导员或院系指定老师；家长进校也需走相同流程。
#    - 消息时间：2023-02-17、2023-03-06、2023-03-13
#
# 3. 🍱 【事件】食堂营业情况更新
#    - 金陵小炒、民族餐厅、九食鱼粉窗口已开放；大唐（诚园餐厅）开门时间约7点多，关门时间接近22:00；菜根谭外卖可正常接收。
#    - 消息时间：2023-02-12 至 2023-03-09
#
# 4. 🧑‍⚕️ 【事件】校医院服务与医保报销政策
#    - 校医院自3月起正常工作，可补牙、拍X光、洁牙（非洗牙），但不能测甲流或做核磁共振（泰康可做，需转诊）。
#    - 报销新规：门诊费用满100元以上才开启统筹报销，低于100元自费；异地就医门诊暂不支持报销。
#    - 医保卡使用：可刷实体卡或支付宝/微信“医保电子凭证”直接结算。
#    - 消息时间：2023-02-12 至 2023-03-09
#
# 5. 📚 【事件】课程与选课相关重要信息
#    - 补退选截止时间：通识课前两周退课无记录，第三周起有痕迹；体育课若第二周停课，则顺延一周计算。
#    - 重修申请已开放，缴费时间另行通知；免修不免考可通过线上系统完成，联系任课教师及教务员审批即可。
#    - 部分课程群号发布：如《职场英语演讲技巧》微信群、《马克思主义与当代中国女性发展》QQ群（762833234）等。
#    - 多门课程考核方式明确，例如：
#      - 《道德与人生》：期末一篇论文，基本不点名。
#      - 《中国书画鉴赏》：1500字手写论文 + 平时签到。
#      - 《走进中华优秀传统文化》：网课任务 + 1000字论文。
#    - 消息时间：2023-02-13 至 2023-03-14
#
# 6. 🔔 【事件】校园码管理规则
#    - 灰码转紫需提交“入校申请”，无需请销假；住校生离校一天以上未刷卡返校，次日凌晨两点后会变灰。
#    - 西门早晨7点开放，全天进出为24小时。
#    - 消息时间：2023-02-12 至 2023-03-09
#
# 7. 🖨️ 【事件】打印与自助服务
#    - 自助打印终端位于行政北楼、图书馆、ITSC；大唐诚园G03室也可打印。
#    - 中英文成绩单可在南大APP或自助机打印，电子版可发送至邮箱。
#    - 消息时间：2023-02-25 至 2023-03-10
#
# 8. 🚴 【事件】生活服务点位更新
#    - 修车点：1栋与3栋之间有师傅；电瓶车维修在环境学院后方。
#    - 干洗店：四栋楼下洗衣缝补处仍在运营，价格参考此前UCC标准。
#    - 废品回收：宿舍楼下澡堂阿姨处可卖废纸。
#    - 消息时间：2023-02-19 至 2023-03-05
#
# 9. 💬 【事件】重要联系方式与资源
#    - 物理系教务员：梅发香（选课）、李娜（学业审核）
#    - 数学院赵进老师邮箱：zhaojin@nju.edu.cn
#    - 南小宝网页端：njuer.top
#    - VPN地址：https://vpn.nju.edu.cn
#    - 消息时间：2023-02-18 至 2023-03-11
#
# 10. ⚠️ 【提醒】其他注意事项
#     - 宿舍用电功率限制约为1000W，超限可能跳闸。
#     - 教室考试期间勿随意进入取物，建议与监考老师沟通。
#     - 统一身份认证冻结通常因密码错误过多，半小时自动解封。
#     - 消息时间：2023-02-26 至 2023-03-11
#
# ---
# 📌 **温馨提示**：以上信息基于群内交流整理，具体执行请以学校官方通知为准。如有变动，请及时关注本科生院、后勤集团及各学院公告。
# ---
# **通知摘要：**
#
# 1. 🏥 【事件】校医院医疗服务与报销说明
#    - 校医院可进行X光检查（周一至周五正常工作日），但无核磁共振设备。
#    - 看病无需转诊，直接刷医保卡或出示电子医保凭证即可，费用为报销后金额。
#    - 体检报告可在“南京大学医院系统”查看；验血结果约半小时出。
#    - 报销周期一般为3-6个月，联系电话：025-83594290（公费医疗办）。
#
# 2. 📅 【事件】重要时间节点提醒
#    - **江苏图采图像采集截止时间**：延期至 **5月12日17:00**（部分学院通知延至15日，请关注本科生院通知）。
#    - **期末考试周安排**：预计为 **6月12日至6月25日**。
#    - **学位英语成绩查询**：暂未开放，预计6月20日后可向教务员咨询。
#    - **五一假期安排**：调休放假5天，非仅放1天。
#
# 3. 🏫 【事件】校园出入与访客管理
#    - 访客可通过“南大APP-信息门户”提交入校申请，需填写审核人（通常为辅导员）及事由。
#    - 家长、校外人员入校需提前申请，公务或特殊事项较易通过，非必要不进校。
#    - 车辆可随访客一同入校，西门、南门均可通行。
#    - 学校开放日（如校庆）可凭身份证登记进入。
#
# 4. 💻 【事件】网络与IT服务
#    - 校园网问题（如无法连接、账号冻结）：账号输错多次会自动冻结30分钟，恢复后可登录。
#    - 统一身份认证异常可尝试切换登录方式（账号密码 vs 扫码）。
#    - 图书馆研讨间网络稳定，适合线上会议。
#    - IT支持群：**926053788**（IT侠）、**1046520564**（信息中心咨询群）。
#
# 5. 🧹 【事件】生活服务信息汇总
#    - **洗衣缝补**：四组团楼下有服务点，营业至晚9点，微信可联系工作人员。
#    - **证件照拍摄**：大唐图文、学则路森与鹿、金鹰海马体等均可，校内图书馆西侧大众书局入口为报告厅。
#    - **打印服务**：图书馆二楼门口有多台可用打印机；逸夫楼暂无自助打印。
#    - **快递收发**：菜根谭可寄顺丰、德邦；圆通妈妈驿站在鼓楼校区校外49号附近。
#    - **电动车维修**：大气楼背后有修车点；充电桩位置可在“微信闪开来电”小程序查询。
#
# 6. 🎓 【事件】课程与教学事务
#    - **通识课挂科**：需参加补考或重修，计入绩点，八周前退课可避免影响。
#    - **体测安排**：
#      - 补测面向19级、22级学生，具体时间见通知（[链接](https://jw.nju.edu.cn/4b/60/c26263a609120/page.htm)）。
#      - 免测者显示“免测”即无需补测，成绩按60分计入，四年加权达50分即可合格。
#    - **研讨间预约**：每日限预约一次，扣分次月恢复。
#    - **空闲教室查询**：使用“网上办事服务大厅”→“空闲教室”功能，比南大APP更准确。
#
# 7. 🚴 【事件】体育与活动场所
#    - **游泳馆开放时间**：
#      - 工作日：18:00–21:00
#      - 周末：14:00–21:00
#    - **健身房**：方肇周体育馆五一期间正常开放。
#    - **十大歌手演出**：C区票位于伟华体育场东侧，排队人数约50–200人。
#
# 8. 🧾 【事件】财务与后勤服务
#    - 校园卡余额过多可转账给他人或在教超消费，不支持直接退款。
#    - 发票报销抬头：南京大学，税号详见学校财务规定。
#    - 工行校门口支行中午休息，下午1点开门。
#
# 9. 📣 【事件】问卷与实习资源
#    - 多项毕业论文/调研问卷正在征集对象，含红包报酬，请留意群内发布。
#    - 实习/兼职群：可联系校学生会外联部或加入“南大实习内推群”。
#    - 社团群信息：
#      - 留学交流群：**821386578**
#      - 弓箭社招新群：**1157895689**
#      - IT相关群：**964644003**（网络攻防）
#
# 10. ⚠️ 【温馨提示】
#     - 宿舍禁用高功率电器（如1000W养生壶），低功率小冰箱一般允许使用。
#     - 自行车请上锁，否则可能被当作无主车辆清理。
#     - 校园码变灰常见原因：出校未刷卡、入校未补刷记录，可联系辅导员协助转码。
#
# ---
# > 注：以上信息基于群聊内容整理，建议涉及政策类事项以官方通知为准。如有变动，请及时关注“本科生院”、“南大APP”及各职能部门公告。
# ---
# **通知摘要：**
#
# 1. 📝 【事件】当代艺术表演课程期末论文提交方式及截止时间
#    - 提交方式：发邮件给任课老师
#    - 截止时间：考试周结束后三周内
#    - 消息发送时间：2023-05-29 16:57:40 / 2023-05-29 17:25:46
#
# 2. 🗓️ 【事件】方婷婷老师《国家安全学》课程期末论文DDL
#    - 截止时间：尚未明确（有偿咨询中）
#    - 相关人员：选修该课程的同学
#    - 消息发送时间：2023-06-06 12:28:41 / 2023-06-11 17:49:47
#
# 3. 🧾 【事件】成绩补录系统开放时间
#    - 开放时间：8月28日至9月1日
#    - 注意事项：部分课程成绩已录入，可登录系统查看
#    - 消息发送时间：2023-08-28 16:21:18 / 2023-08-29 9:47:57
#
# 4. 🎓 【事件】新生报到与老生开学时间
#    - 老生开学时间：2023年9月4日（依据校历）
#    - 新生报到时间：暂未正式通知，预计与老生同步或稍早
#    - 消息来源：南大助手公众号、学生交流
#    - 消息发送时间：2023-07-25 至 2023-08-30
#
# 5. 🖨️ 【事件】大唐打印服务暑期运营情况
#    - 是否开放：暑假期间正常开放
#    - 打印照片：可以打印，建议上午九点至下午五点之间前往
#    - 消息发送时间：2023-07-24 至 2023-07-25
#
# 6. 🏊 【事件】仙林游泳馆暑期开放情况
#    - 是否开放：开放
#    - 使用提示：晚间人较多，注意错峰使用
#    - 消息发送时间：2023-06-19 至 2023-07-20
#
# 7. 📚 【事件】图书馆暑期开放安排
#    - 开放时间：暑期持续开放，仅缩短服务时间；周末照常开放（非暑期时段）
#    - 特别提醒：7月1日起执行暑期时间表，具体闭馆时间为晚上10:30左右
#    - 消息发送时间：2023-07-01 至 2023-08-28
#
# 8. 🍱 【事件】暑期食堂营业信息
#    - 正常营业食堂：四食堂、六食堂、十食堂、民族食堂等
#    - 五食堂：暂时关闭
#    - 消息发送时间：2023-08-12 11:28:12
#
# 9. 💡 【事件】校园网与VPN临时故障通知
#    - 故障时间：2023年7月21日、8月10日至11日
#    - 状态恢复：陆续恢复正常，建议关注官方通知
#    - 消息发送时间：2023-07-21 / 2023-08-10 至 8-11
#
# 10. 🛠️ 【事件】宿舍维修与设施更新
#     - 洗浴系统改造：正在进行中，部分宿舍热水温度异常（过热），建议错峰洗澡
#     - 床帘尺寸参考：床宽0.9米 × 长1.9米，推荐床帘规格为0.9×1.9×1.1米
#     - 消息发送时间：2023-08-26 至 2023-08-27
#
# 11. 🧾 【事件】英文成绩单打印问题
#     - 当前状态：保研期间无法自助打印英文成绩单，行政北楼机器暂无此选项
#     - 建议：待系统恢复后办理，或联系本科生院咨询
#     - 消息发送时间：2023-08-28 17:04:36 至 17:08:42
#
# 12. 🚪 【事件】访客入校政策调整
#     - 开学前允许家长直接进入校园（无需预约）
#     - 可通过国际会议中心入口进入（管理较宽松）
#     - 正式开学后需通过审批流程
#     - 消息发送时间：2023-08-26
#
# 13. 📄 【事件】第二学士学位招生信息发布
#     - 已开通：南京大学官方微信公众号已发布相关通知
#     - 查询方式：关注“南京大学”公众号获取最新动态
#     - 消息发送时间：2023-07-10 12:12:53
#
# 14. 🧑‍🎓 【事件】夏令营与专业咨询信息
#     - 数学系夏令营：不包含专硕项目，学硕亦未招生
#     - 工管院大数据方向：存在争议，传言称研究方向“不够大数据”，建议进一步核实
#     - 电子科学与工程学院导师评价：林军教授性格温和，受学生好评
#     - 消息发送时间：2023-06-13 至 2023-06-30
#
# 15. 📞 【事件】重要联系方式汇总（部分）
#     - 南大学生租房群：1044039571 / 609328490 / 959075742 / 566689000（第4群已升级为2000人群）
#     - 家教群：197117429（满员）、另有新群可咨询
#     - 新生群：728656793（即将满员），另有865543579
#     - 问卷互助群：383798458
#     - 消息发送时间：2023-06-22 至 2023-07-26
#
# ---
#
# > ⚠️ 温馨提示：以上信息基于群聊内容整理，部分事项可能存在变动，请以学校官方通知为准。涉及成绩、选课、证件办理等事务，建议及时联系辅导员或相关职能部门确认。
# ---
# **通知摘要：**
#
# 1. 🗺️ 【信息】群内分享了南京大学鼓楼校区（2017年）和仙林校区（2019年）的电子地图，可通过资产管理处官网获取。
#    - 消息时间：2023-09-01
#
# 2. 🏠 【宿舍】南大仙林学生宿舍“诚园”包含1至5栋；2栋已通热水，初期可能存在水温不稳定或需等待出水的情况。
#    - 提示：若长时间无热水，建议报修。
#    - 消息时间：2023-09-01 至 2023-09-08
#
# 3. 🚿 【浴室】部分宿舍楼公共浴室已关闭（如2栋、4栋），鼓励使用宿舍内热水器；教工浴室开放时间为 **18:30–21:30**，但近期水温偏高。
#    - 消息时间：2023-09-07 至 2023-09-08
#
# 4. 💡 【电费】宿舍电表于近期统一充值，每间宿舍增加约900度电（可能为住宿费上调后的补偿）。
#    - 消息时间：2023-09-19
#
# 5. 💰 【费用】2023年学费+住宿费标准约为 **7880元**（学费6380元 + 住宿费1500元），较往年上涨300元。未自动扣费者可通过“南京大学财务处”公众号或工行APP自助缴纳。
#    - 扣费时间：2023年9月18日左右开始
#    - 消息时间：2023-09-18
#
# 6. 📄 【打印服务】
#    - 鼓楼校区：图书馆一楼右侧休息区、行政北楼一楼、ITSC一楼均设有自助打印机。
#    - 仙林校区：图书馆二楼可正常使用。
#    - 可打印内容：中文成绩单、在读证明、荣誉证书等。
#    - 英文成绩单目前暂停打印（推免期间限制），需签署“放弃保研”承诺书后由教务员协助办理。
#    - 消息时间：2023-09-04 至 2023-09-20
#
# 7. 🧾 【证件与证明】
#    - 学生证补办：前往行政北楼相关办公室办理，需携带身份证、校园卡及一寸照片。
#    - 推荐信/工作证明：联系原任职单位或辅导员开具。
#    - 医保使用：校医院就诊可使用支付宝“电子医保凭证”，无需校园卡。
#    - 消息时间：2023-09-20 至 2023-10-08
#
# 8. 🌐 【网络与系统】
#    - 校园网问题：可尝试清除DNS缓存或参考IT侠网站解决方案。
#    - 统一身份认证故障：曾出现短暂系统崩溃，通常可自行恢复。
#    - 南大App闪退：部分用户反馈存在卡顿现象，建议更新或重启。
#    - 消息时间：2023-09-04 至 2023-09-26
#
# 9. 🚌 【访客与交通】
#    - 家长进校：无需预约，持学生校园卡可在东门、北园小门等处带入（限1–2人）。
#    - 外校参观：可由本校学生带入或通过会议中心入住方式进入。
#    - 消息时间：2023-09-03 至 2023-10-07
#
# 10. 🎓 【学业与课程】
#     - 形策课学分确认为 **0.25分/学期**，共8学期计入总学分。
#     - 体测要求：四年共四次，最终成绩按前三年平均分占50% + 最后一年占50%计算，总分达50分即可合格。
#     - 免修不免考申请：不强制要求课程冲突，八周内处理，不会立即退课。
#     - DIY课程、阅读课群：本科生院官网或课程通知中可查。
#     - 消息时间：2023-09-01 至 2023-10-07
#
# 11. 🛒 【生活服务】
#     - 配钥匙：一栋楼下电脑医院或眼镜店可配。
#     - 照相：大唐打印、汉口路“南缘照相”可拍证件照（价格约15元）。
#     - 冰袋/冰杯：瑞幸、星巴克、罗森便利店或校医院护士站可获取。
#     - 修眼镜：一栋楼下眼镜店支持快速维修。
#     - 消息时间：2023-09-04 至 2023-09-19
#
# 12. 📢 【其他重要信息】
#     - 图书馆自习无需预约（除研讨间外），开放区域正常运行。
#     - 国庆假期安排：10月1日至7日，6日起恢复上课（补周四、五课程）。
#     - 草地音乐节将于10月6日晚在炜华体育场举行。
#     - 消息时间：2023-10-03 至 2023-10-07
#
# ---
# 📌 **温馨提示**：以上信息基于群聊记录整理，具体政策请以学校官方通知为准。如有疑问，建议咨询相关部门或辅导员。
# ---
# **通知摘要：**
#
# 1. 📢 【事件】体测安排调整
#    - 内容：因天气原因，原定于2023年12月10日的室外体测已暂停。无体育课的同学将统一延期至下学期3月补测。
#    - 截止时间 / 发生时间：**2024年3月（具体时间待通知）**
#    - 消息发送时间：2023-12-10 15:04:07
#    - 相关人员：全体需参加体测学生
#
# 2. 🏃‍♂️ 【提醒】体测成绩与毕业要求
#    - 内容：体测四年总分达到50分即可满足毕业要求，无需每年达标；若大四体测成绩≥60分可获“体质健康证书”（无实际用途）。
#    - 截止时间：毕业前完成
#    - 消息发送时间：2023-11-22 至 2023-11-28 多次提及
#    - 相关人员：本科生
#
# 3. 🧑‍🏫 【课程】《看见马克思》作业提交
#    - 内容：有同学咨询该课程作业提交邮箱及截止时间（未明确回复），建议联系任课老师或查看教学立方平台。
#    - 截止时间：待确认（可能临近考试周）
#    - 消息发送时间：2023-12-20 20:59:46
#    - 相关人员：选修该课程学生
#
# 4. 🗓️ 【重要】寒假留校住宿安排
#    - 内容：寒假期间非全程留校者也需集中住宿（如男生九栋、女生六栋等），搬宿时间约为腊月二十七八（约2024年2月上旬）。
#    - 截止时间 / 发生时间：**预计2024年1月底至2月初**
#    - 消息发送时间：2023-12-24 至 2024-01-06
#    - 相关人员：寒假留校学生
#
# 5. 💉 【服务】校医院医疗服务说明
#    - 内容：
#      - 校医院不可拍CT，仅可拍X光；
#      - 可进行流感疫苗接种（需预约）；
#      - 急诊夜间可开药，但挂水服务有限；
#      - 周末仅开放急诊。
#    - 消息发送时间：2023-11-15 至 2024-01-12 多次提及
#    - 相关人员：全体师生
#
# 6. 🛠️ 【生活】电动车维修与充电
#    - 内容：
#      - 大气学院后门有师傅可修电动车（下午1–5点）；
#      - 充电推荐地点：五栋院内、游泳馆门口、十食堂旁、“和园”充电桩；
#      - 可通过“闪开来电”公众号查询可用桩位。
#    - 消息发送时间：2023-11-07 至 2024-01-04
#    - 相关人员：电动车使用者
#
# 7. 🧾 【证明办理】各类官方证明开具方式
#    - 内容：
#      - 百分制成绩单/均分证明 → 行政北楼410盖章；
#      - 在读证明 → 南大APP自助打印或辅导员协助；
#      - 优秀学生等荣誉称号证明 → 南大APP“自助服务”模块打印；
#      - 户籍证明（集体户口）→ 保卫处领取常住人口登记卡。
#    - 消息发送时间：2023-10-11 至 2024-01-04
#    - 相关人员：需要开具证明的学生
#
# 8. 🚗 【出行】家长入校与访客预约
#    - 内容：校外人员可通过“信息门户”微信公众号申请访客入校，由所在院系审核（如商学院为吕亚红老师）。持校园卡也可直接带人进入部分校门。
#    - 消息发送时间：2023-10-19 至 2023-12-29
#    - 相关人员：学生及其亲友
#
# 9. 🎓 【学业】课程考核与免修政策
#    - 内容：
#      - 部分通识课（如《营养不可不说的秘密》）期末为开卷写文章；
#      - 六级6月考试成绩可在研究生开学前出具，用于英语免修申请；
#      - 课程冲突超50%可能被系统自动退课，建议及时沟通教务员。
#    - 消息发送时间：2023-10-17 至 2023-12-14
#    - 相关人员：选课学生
#
# 10. 🧊 【生活服务】冬季实用信息汇总
#     - 内容：
#       - 宿舍热水供应时间：一般至凌晨0:30左右（个别楼可能提前断）；
#       - 菜根谭快递站关门时间：通常为20:00（周末可能更早）；
#       - 图书馆开放时间：早上约7:50开始播放音乐，实际开门接近8:00；
#       - 校园网故障频发，备用方案为使用p2.nju.edu.cn或关注ITS中心通知。
#     - 消息发送时间：2023-10 至 2024-01
#     - 相关人员：全体在校生
#
# ---
# 📌 **温馨提示**：以上信息基于群聊内容整理，部分事项可能存在变动，请以学校官方通知为准。建议关注“南京大学”“南大微学工”“本科生院”等官方微信公众号获取权威信息。

# %%
with open("combine.txt", "w", encoding="utf-8") as f:
    f.write(combine)

print("✅ 已成功保存为txt")
# Out:
# ✅ 已成功保存为txt
